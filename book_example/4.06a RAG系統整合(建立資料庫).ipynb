# %% [markdown]
# # 建立向量資料庫

# %% [markdown]
# # 載入資料

# %%
# 從 langchain_community 套件中匯入需要的 Loader 類別
from langchain_community.document_loaders import DirectoryLoader  # 用來載入整個資料夾
from langchain_community.document_loaders import TextLoader       # 用來載入單一 txt 檔案

# 建立 DirectoryLoader 的實例，用來載入整個資料夾中的文件
loader = DirectoryLoader(
    path="qa_data",      # 指定資料夾名稱，這裡是 "qa_data"
    glob="**/*.txt",     # 使用 glob 模式，支援遞迴搜尋所有子資料夾的 txt 檔案
    loader_cls=TextLoader,           # 指定每個檔案使用 TextLoader 來讀取
    loader_kwargs={"encoding": "utf-8"}  # 傳給 TextLoader 的參數，指定檔案編碼為 UTF-8
)

# 使用 load() 方法載入資料夾中的所有文件
# 這會回傳一個 List，裡面每個元素都是一個 Document 物件
documents = loader.load()

# 列印總共載入了多少筆資料
print(f"總共有{len(documents)}筆資料")

# 列印第一筆文件的內容
# 注意：documents[0] 是一個 Document 物件，如果想只看文字內容，應使用 documents[0].page_content
print(f"第一筆資料的內容如下：\n{documents[0].page_content}")
# Out:
# 總共有8筆資料
# 第一筆資料的內容如下：
# ClementShop 客戶服務詳細問答 - 付款方式
#
# Q1: ClementShop 提供哪些付款方式？
# A1: 目前提供信用卡、行動支付及銀行轉帳三種付款方式。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
#
# Q2: 付款是否安全？
# A2: ClementShop 採用 SSL 安全加密機制，確保交易資料安全。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
#
# Q3: 是否可貨到付款？
# A3: 部分商品支援貨到付款，詳情請參考商品頁面標示。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
#
# Q4: 可以分期付款嗎？
# A4: 部分信用卡支援分期付款，結帳時可選擇可用分期方案。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
#
# Q5: 付款失敗該怎麼辦？
# A5: 請確認付款資訊是否正確或更換付款方式後重新嘗試。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
#
# Q6: 付款後多久會確認訂單？
# A6: 系統會於付款完成後立即更新訂單狀態。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
#
# Q7: 是否可以使用禮物卡或優惠券付款？
# A7: 可以，您可於結帳時輸入禮物卡號或優惠代碼。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
#
# Q8: 銀行轉帳要如何操作？
# A8: 選擇銀行轉帳後，系統會提供專屬帳號，請於期限內完成付款。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
#
# Q9: 是否可索取收據？
# A9: 所有訂單皆會開立電子發票，若需正式收據可另行申請。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
#
# Q10: 付款資訊會被保存嗎？
# A10: ClementShop 僅保存必要之交易紀錄，不會儲存完整信用卡資料。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。

# %% [markdown]
# # 文本分段

# %%
# from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=50
)

split_docs = text_splitter.split_documents(documents)

print(f"原始文件數量：{len(documents)}")
print(f"分段後文件數量：{len(split_docs)}")

for chunk in split_docs:
    print('-------')
    print(chunk.page_content)
    print(chunk.metadata)
# Out:
# 原始文件數量：8
# 分段後文件數量：59
# -------
# ClementShop 客戶服務詳細問答 - 付款方式
#
# Q1: ClementShop 提供哪些付款方式？
# A1: 目前提供信用卡、行動支付及銀行轉帳三種付款方式。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
#
# Q2: 付款是否安全？
# A2: ClementShop 採用 SSL 安全加密機制，確保交易資料安全。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_付款方式.txt'}
# -------
# Q3: 是否可貨到付款？
# A3: 部分商品支援貨到付款，詳情請參考商品頁面標示。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
# {'source': 'qa_data\\QA_付款方式.txt'}
# -------
# Q4: 可以分期付款嗎？
# A4: 部分信用卡支援分期付款，結帳時可選擇可用分期方案。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
# {'source': 'qa_data\\QA_付款方式.txt'}
# -------
# Q5: 付款失敗該怎麼辦？
# A5: 請確認付款資訊是否正確或更換付款方式後重新嘗試。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
#
# Q6: 付款後多久會確認訂單？
# A6: 系統會於付款完成後立即更新訂單狀態。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
# {'source': 'qa_data\\QA_付款方式.txt'}
# -------
# Q7: 是否可以使用禮物卡或優惠券付款？
# A7: 可以，您可於結帳時輸入禮物卡號或優惠代碼。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
# {'source': 'qa_data\\QA_付款方式.txt'}
# -------
# Q8: 銀行轉帳要如何操作？
# A8: 選擇銀行轉帳後，系統會提供專屬帳號，請於期限內完成付款。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
# {'source': 'qa_data\\QA_付款方式.txt'}
# -------
# Q9: 是否可索取收據？
# A9: 所有訂單皆會開立電子發票，若需正式收據可另行申請。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
#
# Q10: 付款資訊會被保存嗎？
# A10: ClementShop 僅保存必要之交易紀錄，不會儲存完整信用卡資料。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
# {'source': 'qa_data\\QA_付款方式.txt'}
# -------
# ClementShop 客戶服務詳細問答 - 出貨管理與通知
#
# Q1: 出貨時間需要多久？
# A1: 一般商品會於付款完成後 2-3 個工作天內出貨。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
# {'source': 'qa_data\\QA_出貨管理與通知.txt'}
# -------
# Q2: 如何得知商品已出貨？
# A2: 系統會於出貨後寄送出貨通知信並提供追蹤號碼。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
# {'source': 'qa_data\\QA_出貨管理與通知.txt'}
# -------
# Q3: 可以指定出貨日期嗎？
# A3: 目前暫不支援指定出貨日期服務。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。
# {'source': 'qa_data\\QA_出貨管理與通知.txt'}
# -------
# Q4: 出貨後多久可以收到商品？
# A4: 依地區不同，通常出貨後 1-3 個工作天內可送達。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
# {'source': 'qa_data\\QA_出貨管理與通知.txt'}
# -------
# Q5: 可以合併出貨嗎？
# A5: 若多筆訂單同時成立且尚未出貨，可申請合併出貨。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
#
# Q6: 出貨通知信沒收到怎麼辦？
# A6: 請先檢查垃圾信件夾，若仍未收到，請聯繫客服。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。
# {'source': 'qa_data\\QA_出貨管理與通知.txt'}
# -------
# Q7: 是否提供國際出貨？
# A7: 目前 ClementShop 僅提供台灣地區配送服務。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。
#
# Q8: 出貨時會附發票嗎？
# A8: 所有訂單均為電子發票，不隨貨附紙本發票。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
# {'source': 'qa_data\\QA_出貨管理與通知.txt'}
# -------
# Q9: 商品出貨後可以更改收件地址嗎？
# A9: 出貨後無法更改收件地址，請於出貨前確認資料。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
#
# Q10: 商品缺貨怎麼處理？
# A10: 若商品缺貨，系統將自動通知您並辦理退款或更換方案。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_出貨管理與通知.txt'}
# -------
# ClementShop 客戶服務詳細問答 - 會員註冊
#
# Q1: 如何加入 ClementShop 成為會員？
# A1: 請至 ClementShop 首頁右上角點選「註冊」，填寫基本資料後即可成為會員。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
#
# Q2: 註冊會員是否需要收費？
# A2: ClementShop 會員註冊完全免費，無需支付任何費用。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。
# {'source': 'qa_data\\QA_會員註冊.txt'}
# -------
# Q3: 會員註冊需要提供哪些資料？
# A3: 您需提供姓名、電子郵件信箱及設定登入密碼，並確認服務條款。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。
# {'source': 'qa_data\\QA_會員註冊.txt'}
# -------
# Q4: 註冊後是否可以更改電子郵件？
# A4: 電子郵件為會員帳號，不可自行更改。如需修改，請聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
# {'source': 'qa_data\\QA_會員註冊.txt'}
# -------
# Q5: 忘記密碼怎麼辦？
# A5: 請於登入頁面點選「忘記密碼」，系統將寄送重設密碼連結至您的電子郵件。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
#
# Q6: 如何確認是否註冊成功？
# A6: 完成註冊後，系統會自動寄出確認信至您的電子郵件信箱。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_會員註冊.txt'}
# -------
# Q7: 是否可以使用社群帳號登入？
# A7: 目前 ClementShop 支援 Google 及 Facebook 帳號快速登入功能。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。
# {'source': 'qa_data\\QA_會員註冊.txt'}
# -------
# Q8: 會員帳號會不會被停權？
# A8: 若違反使用條款或有不當行為，ClementShop 有權暫停或終止帳號使用權。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_會員註冊.txt'}
# -------
# Q9: 如何刪除會員帳號？
# A9: 您可透過客服中心申請帳號刪除，處理時間約 3-5 個工作天。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
#
# Q10: 會員註冊有年齡限制嗎？
# A10: ClementShop 會員須年滿 18 歲方可註冊。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。
# {'source': 'qa_data\\QA_會員註冊.txt'}
# -------
# ClementShop 客戶服務詳細問答 - 理賠
#
# Q1: 商品在運送中損壞怎麼辦？
# A1: 請於收到商品後三日內聯繫客服並提供照片，我們將協助理賠。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_理賠.txt'}
# -------
# Q2: 理賠需要哪些資料？
# A2: 請提供訂單編號、損壞商品照片與聯絡資訊。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_理賠.txt'}
# -------
# Q3: 理賠處理時間多久？
# A3: 理賠申請確認後，通常於 5-7 個工作天內完成處理。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
#
# Q4: 理賠金額如何計算？
# A4: 依實際損壞情形與商品價值核定理賠金額。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_理賠.txt'}
# -------
# Q5: 理賠金如何退款？
# A5: 理賠金會以原付款方式退還至您的帳戶。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
# {'source': 'qa_data\\QA_理賠.txt'}
# -------
# Q6: 是否需寄回損壞商品？
# A6: 視情況而定，客服會告知是否需寄回檢驗。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
#
# Q7: 理賠申請可以取消嗎？
# A7: 若尚未完成審核，您可提出取消申請。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
# {'source': 'qa_data\\QA_理賠.txt'}
# -------
# Q8: 理賠申請被拒絕會通知嗎？
# A8: 會，系統將以電子郵件通知理賠結果與理由。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
#
# Q9: 理賠進度如何查詢？
# A9: 您可登入會員中心查詢理賠申請進度。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
# {'source': 'qa_data\\QA_理賠.txt'}
# -------
# Q10: 理賠有期限限制嗎？
# A10: 請於收貨後七日內提出理賠申請，逾期恕不受理。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_理賠.txt'}
# -------
# ClementShop 客戶服務詳細問答 - 訂購方式
#
# Q1: 如何在 ClementShop 下訂單？
# A1: 請登入會員後，將商品加入購物車並依指示完成結帳流程。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
# {'source': 'qa_data\\QA_訂購方式.txt'}
# -------
# Q2: 是否可使用電話訂購？
# A2: 目前僅支援線上訂購，暫不提供電話下單服務。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
# {'source': 'qa_data\\QA_訂購方式.txt'}
# -------
# Q3: 可以同時購買多項商品嗎？
# A3: 可以，您可將多項商品加入購物車後一次結帳。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。
# {'source': 'qa_data\\QA_訂購方式.txt'}
# -------
# Q4: 下單後可以修改訂單嗎？
# A4: 訂單成立後無法修改，若需變更，請聯繫客服協助取消後重新下單。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
#
# Q5: 如何確認訂單是否成立？
# A5: 訂單完成後，系統會寄送訂單確認信至您的電子郵件信箱。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。
# {'source': 'qa_data\\QA_訂購方式.txt'}
# -------
# Q6: 可以為別人訂購商品嗎？
# A6: 可以，您可於結帳時填寫不同的收件人資料。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
# {'source': 'qa_data\\QA_訂購方式.txt'}
# -------
# Q7: 是否有最低消費限制？
# A7: 目前 ClementShop 沒有設定最低消費金額限制。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
# {'source': 'qa_data\\QA_訂購方式.txt'}
# -------
# Q8: 可以預訂尚未上市的商品嗎？
# A8: 若商品頁面標示可預購，您可依指示完成預購流程。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
#
# Q9: 訂單中可以選擇不同付款方式嗎？
# A9: 同一筆訂單僅能選擇一種付款方式。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
#
# Q10: 如何查看訂單進度？
# A10: 您可登入會員中心，於「訂單查詢」中查看出貨與配送狀態。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
# {'source': 'qa_data\\QA_訂購方式.txt'}
# -------
# ClementShop 客戶服務詳細問答 - 退貨
#
# Q1: 如何申請退貨？
# A1: 請登入會員中心，於訂單詳情中點選「申請退貨」。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
#
# Q2: 退貨期限是多久？
# A2: 收到商品後七日內可申請退貨。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。
# {'source': 'qa_data\\QA_退貨.txt'}
# -------
# Q3: 退貨需要支付運費嗎？
# A3: 若為商品瑕疵或出貨錯誤，退貨運費由 ClementShop 負擔。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
# {'source': 'qa_data\\QA_退貨.txt'}
# -------
# Q4: 退貨商品需要保持什麼狀態？
# A4: 商品須保持全新未使用、包裝完整並附原始發票。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
#
# Q5: 退貨申請審核多久？
# A5: 客服將於收到申請後 3 個工作天內完成審核。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
# {'source': 'qa_data\\QA_退貨.txt'}
# -------
# Q6: 退款會退到哪裡？
# A6: 退款將退回原付款帳戶或信用卡。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
#
# Q7: 退貨後多久會收到退款？
# A7: 退款流程約需 5-10 個工作天完成。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_退貨.txt'}
# -------
# Q8: 是否可部分退貨？
# A8: 可以，您可選擇退回部分商品。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。
#
# Q9: 退貨申請被拒會通知嗎？
# A9: 會，系統會寄送電子郵件說明原因。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
# {'source': 'qa_data\\QA_退貨.txt'}
# -------
# Q10: 哪些商品不接受退貨？
# A10: 客製化、易腐壞或已拆封之商品恕不接受退貨。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
# {'source': 'qa_data\\QA_退貨.txt'}
# -------
# ClementShop 客戶服務詳細問答 - 運貨寄送
#
# Q1: ClementShop 使用哪些物流公司？
# A1: 我們與多家物流夥伴合作，包括黑貓宅急便與中華郵政。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q2: 配送地區有哪些？
# A2: 目前配送範圍為全台本島及部分離島地區。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q3: 是否提供指定時段配送？
# A3: 部分物流支援時段選擇，詳情請參考結帳頁面選項。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q4: 運費如何計算？
# A4: 運費依商品重量與配送地區自動計算，結帳時會顯示總金額。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q5: 訂單金額達多少可免運？
# A5: 單筆訂單滿 NT$1,000 即享免運優惠。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q6: 可以寄送至超商嗎？
# A6: 部分商品支援超商取貨，您可於結帳時選擇指定門市。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q7: 若配送失敗怎麼辦？
# A7: 若物流無法送達，商品將退回並通知您重新安排配送。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q8: 如何查詢物流狀態？
# A8: 您可於「訂單查詢」中查看物流追蹤資訊。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q9: 可否寄送至海外？
# A9: 目前暫不提供海外配送服務。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# Q10: 配送時會聯絡收件人嗎？
# A10: 物流人員於配送前會以電話或簡訊方式通知收件人。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。
# {'source': 'qa_data\\QA_運貨寄送.txt'}
# -------
# ClementShop 客戶服務詳細問答 - 電子發票
#
# Q1: ClementShop 是否開立電子發票？
# A1: 是的，所有訂單均開立合法電子發票。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
#
# Q2: 如何查詢我的電子發票？
# A2: 您可於會員中心的「發票紀錄」中查詢並下載電子發票。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_電子發票.txt'}
# -------
# Q3: 電子發票何時開立？
# A3: 電子發票會於訂單完成出貨後自動開立。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_電子發票.txt'}
# -------
# Q4: 可以指定統一編號嗎？
# A4: 可以，請於結帳時填寫統一編號與發票抬頭。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。
# {'source': 'qa_data\\QA_電子發票.txt'}
# -------
# Q5: 電子發票可以改寄紙本嗎？
# A5: 目前僅提供電子發票，不提供紙本寄送服務。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。
# {'source': 'qa_data\\QA_電子發票.txt'}
# -------
# Q6: 電子發票是否可列印？
# A6: 您可自行下載 PDF 檔案後列印使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。
#
# Q7: 若發票資訊填錯可以修改嗎？
# A7: 發票開立後不得修改，請於下單前確認資料正確。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。
# {'source': 'qa_data\\QA_電子發票.txt'}
# -------
# Q8: 如何捐贈電子發票？
# A8: 您可於結帳時選擇捐贈發票並輸入受捐單位代碼。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。
# {'source': 'qa_data\\QA_電子發票.txt'}
# -------
# Q9: 中獎發票如何領獎？
# A9: 中獎發票依財政部公告方式兌領，ClementShop 不代辦領獎。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。
# {'source': 'qa_data\\QA_電子發票.txt'}
# -------
# Q10: 發票會寄到我的電子郵件嗎？
# A10: 發票開立後會寄送通知信至您註冊的電子郵件信箱。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。
# {'source': 'qa_data\\QA_電子發票.txt'}

# %% [markdown]
# # 將資料存進向量資料庫(Chroma)

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# 設定資料庫路徑
persist_dir = "./chroma_db"

# 建立嵌入模型
embeddings = HuggingFaceEmbeddings(model_name="BAAI/bge-large-zh-v1.5")

# 建立或載入現有的 Chroma 向量資料庫
vector_store = Chroma(
    collection_name="clementshop_qa",     # collection 名稱（相當於一個資料表）
    embedding_function=embeddings,        # 指定嵌入函式
    persist_directory=persist_dir         # 向量資料儲存路徑
)

#######################################################################
# 為了避免向量資料庫中重複新增相同的文件，程式會在必要時先清空舊的 collection，
# 再重新建立一個空的 collection，以確保資料庫保持整潔與一致性。
# 你可以依需求選擇是否啟用此操作，如果希望保留舊資料，也可以跳過清空步驟。

# 清空現有 collection
vector_store.delete_collection()

# 重新建立一個新的空 collection
vector_store = Chroma(
    collection_name="clementshop_qa",  # collection 名稱（相當於一個資料表）
    embedding_function=embeddings,
    persist_directory=persist_dir
)
#
#######################################################################


# 新增文件資料
vector_store.add_documents(split_docs)

print("✅ 成功新增新資料至 Chroma。")
# Out:
# ✅ 成功新增新資料至 Chroma。

# %%
# 測試
similar_docs = vector_store.similarity_search("東西品質太差了，我想要退貨！", k=5)
similar_docs
# Out:
# [Document(id='ac7482f8-e7f2-4ee3-a5ed-b27b8e37ebda', metadata={'source': 'qa_data\\QA_退貨.txt'}, page_content='Q10: 哪些商品不接受退貨？\nA10: 客製化、易腐壞或已拆封之商品恕不接受退貨。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。'),
#  Document(id='818269b7-4a2b-4690-9d09-13aed2a83bd9', metadata={'source': 'qa_data\\QA_退貨.txt'}, page_content='Q4: 退貨商品需要保持什麼狀態？\nA4: 商品須保持全新未使用、包裝完整並附原始發票。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。\n\nQ5: 退貨申請審核多久？\nA5: 客服將於收到申請後 3 個工作天內完成審核。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。'),
#  Document(id='f207e8f7-9007-49ec-b327-28d98f340900', metadata={'source': 'qa_data\\QA_退貨.txt'}, page_content='Q3: 退貨需要支付運費嗎？\nA3: 若為商品瑕疵或出貨錯誤，退貨運費由 ClementShop 負擔。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。'),
#  Document(id='071fbe2f-422b-4157-acc1-278d393069a4', metadata={'source': 'qa_data\\QA_退貨.txt'}, page_content='ClementShop 客戶服務詳細問答 - 退貨\n\nQ1: 如何申請退貨？\nA1: 請登入會員中心，於訂單詳情中點選「申請退貨」。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。\n\nQ2: 退貨期限是多久？\nA2: 收到商品後七日內可申請退貨。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。'),
#  Document(id='b83a7896-5f2b-4f13-ad95-c1b4b76def0c', metadata={'source': 'qa_data\\QA_退貨.txt'}, page_content='Q8: 是否可部分退貨？\nA8: 可以，您可選擇退回部分商品。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。\n\nQ9: 退貨申請被拒會通知嗎？\nA9: 會，系統會寄送電子郵件說明原因。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。 所有流程皆可於會員中心即時查詢進度，讓您清楚掌握每一步狀態。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。')]

# %%
# 測試
similar_docs = vector_store.similarity_search("你們會開發票嗎？", k=5)
similar_docs
# Out:
# [Document(id='ad079d88-bbf4-43a9-a6c5-014d1520a578', metadata={'source': 'qa_data\\QA_電子發票.txt'}, page_content='Q3: 電子發票何時開立？\nA3: 電子發票會於訂單完成出貨後自動開立。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 所有個人資料均受到嚴格保護，並依據個資法相關規範進行處理。'),
#  Document(id='cdfbe762-34ca-46a4-b1f7-d2ff28011e0e', metadata={'source': 'qa_data\\QA_電子發票.txt'}, page_content='Q6: 電子發票是否可列印？\nA6: 您可自行下載 PDF 檔案後列印使用。 若申請內容涉及退款或帳號異動，處理時間將依銀行及系統作業日為準。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。\n\nQ7: 若發票資訊填錯可以修改嗎？\nA7: 發票開立後不得修改，請於下單前確認資料正確。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 如遇特殊情況，我們將主動以電子郵件或簡訊通知您最新進度。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。'),
#  Document(id='8ea638e0-b70d-4016-ac64-33310e7596b0', metadata={'source': 'qa_data\\QA_電子發票.txt'}, page_content='ClementShop 客戶服務詳細問答 - 電子發票\n\nQ1: ClementShop 是否開立電子發票？\nA1: 是的，所有訂單均開立合法電子發票。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。\n\nQ2: 如何查詢我的電子發票？\nA2: 您可於會員中心的「發票紀錄」中查詢並下載電子發票。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。'),
#  Document(id='fc73b49e-ed8b-4d19-aaeb-8d7420133747', metadata={'source': 'qa_data\\QA_電子發票.txt'}, page_content='Q10: 發票會寄到我的電子郵件嗎？\nA10: 發票開立後會寄送通知信至您註冊的電子郵件信箱。 若您在規定時間內未收到通知或確認信，請檢查垃圾郵件夾或聯繫客服協助處理。 若您在操作過程中遇到任何問題，建議您可先確認網路連線狀況，或重新整理頁面再試一次。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。'),
#  Document(id='50e8ed92-a618-44a7-8550-e3b5b8ed2fef', metadata={'source': 'qa_data\\QA_電子發票.txt'}, page_content='Q8: 如何捐贈電子發票？\nA8: 您可於結帳時選擇捐贈發票並輸入受捐單位代碼。 請注意，部分作業可能因例假日或物流延誤而稍有影響，敬請見諒。 ClementShop 的系統會即時更新相關資訊，確保您的資料與訂單狀態保持最新。 我們建議您於完成操作後截圖保存，以便日後查詢紀錄或問題申訴使用。 客服團隊提供每日 09:00 至 18:00 線上支援，將協助您解決各類問題。')]
