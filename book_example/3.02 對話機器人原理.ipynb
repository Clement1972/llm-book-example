# %% [markdown]
# # 對話機器人原理

# %% [markdown]
# # 選擇模型
# 請自由任意選擇下面兩個模型之一來進行範例

# %% [markdown]
# ## Gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

API_KEY = "這邊請改成你自己的API_KEY值"
model_name = 'gemini-2.5-flash'

llm = ChatGoogleGenerativeAI(
    model=model_name,
    google_api_key=API_KEY
)

# %% [markdown]
# ## LM Studio 或 Ollama

# %%
from langchain_openai import ChatOpenAI
model_name = 'gemma-3-12b-it'  # 指定模型名稱，模型名稱會根據下載的模型不同而改變

# 根據使用LM Studio或Ollama來選擇適當的伺服器URL
base_url = 'http://localhost:1234/v1'  # LM Studio 本地伺服器的URL
# base_url = 'http://localhost:11434/v1' # Ollama 本地伺服器的URL

llm = ChatOpenAI(
    model=model_name,
    openai_api_key="not-needed",
    openai_api_base=base_url 
)

# %% [markdown]
# ## 測試模型

# %%
from langchain_core.messages import HumanMessage
messages = [
    HumanMessage("機器學習的定義")
]
result = llm.invoke(messages)
print(result.content)
# Out:
# 機器學習 (Machine Learning, ML) 是**人工智慧 (Artificial Intelligence, AI) 的一個子領域**，其核心思想是讓電腦系統能夠**從數據中『學習』**，而不是透過明確的指令或程式碼來執行特定任務。
#
# 更具體地說，機器學習可以定義為：
#
# **透過開發和應用演算法，使電腦系統能夠從經驗（即數據）中自動識別模式、做出預測或決策，並隨著時間的推移和更多數據的輸入，自動提升其在特定任務上的性能，而無需被明確地編程來完成每個具體的步驟。**
#
# 簡單來說，可以將其理解為：**教電腦如何自己學習，而不是告訴它每一個步驟。**
#
# **核心特點：**
#
# 1.  **從數據中學習 (Learning from Data)：** 機器學習模型透過分析大量的歷史數據來發現其中的規律、趨勢和關聯性。
# 2.  **無需明確編程 (Without Explicit Programming)：** 與傳統程式設計不同，開發者不會為每個可能的情況編寫硬性規則。相反，他們建立一個學習演算法，讓它自己從數據中推斷出規則。
# 3.  **模式識別與預測 (Pattern Recognition and Prediction)：** 學習的結果是模型能夠識別新的數據中的模式，並基於這些模式做出預測或分類。
# 4.  **性能提升 (Performance Improvement)：** 隨著模型接觸到的數據量越多、質量越好，其在特定任務上的表現會自動變得更好。
# 5.  **演算法 (Algorithms)：** 機器學習的基石是各種演算法，它們定義了模型如何從數據中學習。常見的演算法包括線性迴歸、決策樹、支持向量機、神經網路等。
#
# **例子：**
#
# *   **圖像識別：** 訓練模型辨識照片中的貓或狗，它會從數百萬張圖片中學習貓狗的特徵，而不是被告知「有鬍鬚的是貓，會汪汪叫的是狗」。
# *   **推薦系統：** 電商網站根據你過去的購買和瀏覽記錄，推薦你可能喜歡的商品。
# *   **垃圾郵件過濾：** 機器學習模型分析大量的垃圾郵件和非垃圾郵件，學習兩者之間的區別，從而自動過濾新收到的郵件。
# *   **語音識別：** 辨識口語指令，如Siri或Google助理。
#
# ...

# %% [markdown]
# # 開始範例

# %% [markdown]
# ## 對話測試

# %%
from langchain_core.messages import HumanMessage, SystemMessage
def chat(text):
    messages = [
        HumanMessage(text)
    ]
    result = llm.invoke(messages)
    print(result.content)

# %%
chat("我的名字是什麼？")
# Out:
# 很抱歉，我不知道您的名字。
#
# 我是一个人工智能，无法获取您的个人信息。

# %%
chat("我是陳仁政！")
# Out:
# 好的，陳仁政。

# %%
chat("那現在你知道我的名字是什麼了嗎？")
# Out:
# 不，我不知道你的名字。
#
# 作為一個AI語言模型，我沒有記憶功能來記住你的個人資訊，例如你的名字。每次對話對我來說都是獨立的，我也無法識別或儲存你的身份。

# %% [markdown]
# ## Chat Message List

# %%
messages = [
    SystemMessage("你是一個個人助理"),
    HumanMessage("我的名字是什麼？")
]
result = llm.invoke(messages)
result
# Out:
# AIMessage(content='我很抱歉，我不知道你的名字。\n\n我是一個AI，不會存儲或知道你的個人資訊。如果你願意，可以告訴我你的名字，這樣我以後就可以這樣稱呼你。', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--f445215b-101e-4d66-81c9-620321d1eb3c-0', usage_metadata={'input_tokens': 9, 'output_tokens': 560, 'total_tokens': 569, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 519}})

# %%
messages = [
    SystemMessage("你是一個個人助理"),
    HumanMessage("我的名字是什麼？"),
    result,
    HumanMessage("我是陳仁政！")
]

result_step2 = llm.invoke(messages)
print(result_step2.content)
# Out:
# 好的，陳仁政！很高興認識你！
#
# 我會記住這個名字。如果你以後需要任何幫助，儘管告訴我。

# %%
messages = [
    SystemMessage("你是一個個人助理"),
    HumanMessage("我的名字是什麼？"),
    result,
    HumanMessage("我是陳仁政！"),
    result_step2,
    HumanMessage("那現在你知道我的名字是什麼了嗎？")
]

result_step3 = llm.invoke(messages)
print(result_step3.content)
# Out:
# 是的，陳仁政！
#
# 在我們目前的對話中，我確實知道你的名字了。我會記住你剛剛告訴我的這個資訊，並在這次交流中稱呼你為陳仁政。
