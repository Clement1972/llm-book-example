# %% [markdown]
# # 串流式對話機器人

# %% [markdown]
# # 選擇模型
# 請自由任意選擇下面兩個模型之一來進行範例

# %% [markdown]
# ## Gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

API_KEY = "這邊請改成你自己的API_KEY值"
model_name = 'gemini-2.5-flash'

llm = ChatGoogleGenerativeAI(
    model=model_name,
    google_api_key=API_KEY
)

# %% [markdown]
# ## LM Studio 或 Ollama

# %%
from langchain_openai import ChatOpenAI
model_name = 'gemma-3-12b-it'  # 指定模型名稱，模型名稱會根據下載的模型不同而改變

# 根據使用LM Studio或Ollama來選擇適當的伺服器URL
base_url = 'http://localhost:1234/v1'  # LM Studio 本地伺服器的URL
# base_url = 'http://localhost:11434/v1' # Ollama 本地伺服器的URL

llm = ChatOpenAI(
    model=model_name,
    openai_api_key="not-needed",
    openai_api_base=base_url 
)

# %% [markdown]
# ## 測試模型

# %%
from langchain_core.messages import HumanMessage
messages = [
    HumanMessage("機器學習的定義")
]
result = llm.invoke(messages)
print(result.content)
# Out:
# 機器學習 (Machine Learning, ML) 是一個數據科學領域，它讓電腦系統能夠**從數據中學習，而無需被明確地編程來執行特定任務**。
#
# 以下是機器學習的幾個關鍵定義和核心概念：
#
# 1.  **Arthur Samuel 的經典定義 (1959 年):**
#     > 「機器學習是一個研究領域，它賦予電腦在沒有被明確編程的情況下學習的能力。」
#     這是一個廣為人知的早期定義，強調了「無需明確編程」的核心思想。
#
# 2.  **Tom M. Mitchell 的現代定義 (1997 年):**
#     > 「如果一個電腦程式在**任務 T** 上的性能，由**性能指標 P** 來衡量，隨著**經驗 E** 的增加而提高，那麼我們就說這個程式從經驗中學習了。」
#     這個定義更為精確和可操作，它將學習的過程分解為三個關鍵要素：
#     *   **經驗 E (Experience):** 指的是程式所接觸到的訓練數據。例如，對於一個圖像識別系統，E 就是大量的帶有標籤的圖像數據。
#     *   **任務 T (Task):** 指的是程式需要完成的具體目標。例如，識別圖片中的貓狗，預測房價，翻譯文本等。
#     *   **性能指標 P (Performance Measure):** 用於量化程式在任務 T 上表現好壞的標準。例如，分類的準確率、預測的均方誤差、F1 分數等。
#
# **核心思想：**
#
# 機器學習的核心在於讓電腦透過分析大量數據來發現其中的模式、趨勢和關聯性，並基於這些發現來構建一個「模型」。這個模型隨後可以用於對新的、未見過的數據做出預測、決策或分類。
#
# **與傳統編程的區別：**
#
# *   **傳統編程：** 人類工程師編寫明確的、一步一步的指令來告訴電腦如何解決問題。當問題複雜或數據量龐大時，編寫這些規則變得非常困難甚至不可能。
#     *   *輸入數據 + 規則 (程式碼) = 輸出答案*
# *   **機器學習：** 工程師不直接編寫解決問題的規則，而是提供數據和一個學習演算法。演算法會從數據中自動學習規則或模式，然後生成一個模型來解決問題。
#     *   *輸入數據 + 答案 (標籤) = 輸出規則 (模型)*
#     *   *新輸入數據 + 輸出規則 (模型) = 輸出預測/答案*
#
# **機器學習的主要類型：**
#
# 1.  **監督式學習 (Supervised Learning):** 訓練數據包含輸入和對應的正確輸出（標籤）。模型從這些「標記」的數據中學習映射關係，然後預測新數據的輸出。
#     *   **分類 (Classification):** 預測離散的類別（例如：垃圾郵件/非垃圾郵件、貓/狗）。
#     *   **迴歸 (Regression):** 預測連續的數值（例如：房價、氣溫）。
# 2.  **非監督式學習 (Unsupervised Learning):** 訓練數據沒有標籤。模型嘗試在數據中發現隱藏的結構、模式或分組。
#     *   **聚類 (Clustering):** 將相似的數據點分組（例如：客戶分群）。
#     *   **降維 (Dimensionality Reduction):** 減少數據的特徵數量，同時保留其重要信息。
# 3.  **強化學習 (Reinforcement Learning):** 代理（Agent）在一個環境中與之交互，通過試錯學習。根據其行為獲得獎勵或懲罰，目標是最大化長期獎勵。
#     *   應用於遊戲、機器人控制等。
#
# **總而言之，機器學習賦予了電腦從數據中自動學習、改進和做出決策的能力，是實現人工智能的關鍵技術之一。**

# %% [markdown]
# # 開始範例

# %% [markdown]
# ## 串流式輸出

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [HumanMessage("機器學習的定義")]

# 使用串流模式呼叫模型，逐步輸出回應內容
# llm.stream() 會回傳一個可逐項讀取的生成結果
for chunk in llm.stream(messages):
    # 每次取得部分內容 (chunk)，立即輸出而不換行
    print(chunk.content, end="", flush=True)

# 串流結束後可視需要換行或做後續處理
print()  # 結束後換行
# Out:
# 機器學習 (Machine Learning, ML) 是人工智慧 (Artificial Intelligence, AI) 的一個分支，它讓電腦系統能夠**從數據中學習，而無需被明確地編程**。
#
# 更具體地說，它的核心思想是：
#
# 1.  **從數據中學習模式 (Learning from Data Patterns)：**
#     *   傳統的程式設計需要人類為每種可能的輸入和輸出明確地編寫規則。
#     *   機器學習則透過給予演算法大量的數據（例如圖片、文字、數字等），讓它自動識別數據中的模式、關聯和結構。演算法會調整其內部參數，以找到最佳的數據表示方式或預測模型。
#
# 2.  **無需明確編程 (Without Explicit Programming)：**
#     *   這意味著我們不需要告訴電腦「如果輸入是這樣，就輸出那樣」的精確指令。
#     *   相反，我們提供數據、一個學習目標（例如預測房價、識別圖片中的貓狗），以及一個學習演算法，電腦自己會從數據中歸納出規則或模型。
#
# 3.  **預測和決策 (Prediction and Decision Making)：**
#     *   一旦模型從數據中學習完畢，它就可以用來對新的、未見過的數據進行預測、分類、決策或生成內容。
#     *   例如，一個學習了大量房價數據的模型，可以預測新房子的價格；一個學習了垃圾郵件的模型，可以識別新的垃圾郵件。
#
# 4.  **性能提升 (Performance Improvement)：**
#     *   隨著更多的數據被輸入和處理，機器學習模型的性能通常會隨之提高。它能夠不斷地自我優化和改進其預測或決策的準確性。
#
# **總結來說，機器學習是透過演算法分析數據，自動從中發現模式，並利用這些模式來進行預測、分類或決策，而無需人類為每一步明確編寫規則的技術。**
#
# **常見的機器學習類型包括：**
#
# *   **監督式學習 (Supervised Learning)：** 使用帶有標籤的數據（已知輸入和對應輸出的數據）進行訓練，例如預測房價、圖片分類。
# *   **非監督式學習 (Unsupervised Learning)：** 使用沒有標籤的數據進行訓練，旨在發現數據內在的結構或模式，例如客戶分群、降維。
# *   **強化學習 (Reinforcement Learning)：** 讓代理（Agent）在環境中透過試錯學習，根據獎勵和懲罰來優化其行為，例如玩遊戲、機器人控制。
#
# 機器學習已經廣泛應用於我們的日常生活中，例如推薦系統（Netflix、Amazon）、語音識別（Siri、Alexa）、圖像識別（人臉解鎖）、垃圾郵件過濾、自動駕駛等。

# %% [markdown]
# # 串流式對話機器人

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
class ChatBot:
    def __init__(self, llm):
        self.llm = llm  # LLM 是對話機器人的大腦
        
        # 初始化對話記錄，包含系統提示詞
        self.messages = [SystemMessage("你是一個個人助理")]

    # 一般版：一次性呼叫模型，整段生成完才回傳
    def chat(self, text):
        # 將使用者輸入加入記錄
        self.messages.append(HumanMessage(text))        
        # 呼叫模型生成完整回覆
        response = self.llm.invoke(self.messages)
        # 將模型回覆加入記錄
        self.messages.append(response)
        # 回傳文字內容
        return response.content

    # 串流版：使用 yield 逐步回傳生成結果
    def chat_stream(self, text):
        # 將使用者輸入加入記錄
        self.messages.append(HumanMessage(text))
        
        # 用於累積完整回覆
        full_response = ""

        # 使用 llm.stream() 逐步獲取生成內容
        for chunk in self.llm.stream(self.messages):
            # chunk.content 為每次生成的一小段文字
            if chunk.content:
                full_response += chunk.content
                # 使用 yield 將部分內容回傳給外部呼叫者
                yield chunk.content

        # 串流結束後，將完整回覆加入記錄
        self.messages.append(AIMessage(full_response))

# %%
bot = ChatBot(llm)
# 逐步接收生成的文字並即時顯示
for chunk in bot.chat_stream("機器學習的定義"):
    print(chunk, end="", flush=True)
print()  # 最後換行
# Out:
# 機器學習（Machine Learning，簡稱 ML）是人工智慧（AI）的一個分支領域，它讓電腦系統能夠從數據中學習，並根據這些學習到的模式和經驗來改進其性能，而無需被明確地編程來執行每一項任務。
#
# 換句話說，機器學習的目標是讓電腦能夠像人類一樣，透過觀察、經驗和數據來「學習」，並從中找出規律、趨勢或模式。然後利用這些學習成果來做出預測、決策或分類。
#
# **核心概念：**
#
# 1.  **從數據中學習 (Learning from Data)：** 機器學習模型不是透過硬編碼的規則來運作，而是透過分析大量的數據來自動發現數據中的模式和關係。
# 2.  **不需明確編程 (Not Explicitly Programmed)：** 傳統程式設計需要開發者為每個可能的情況編寫詳細的指令。機器學習則不同，開發者編寫一個學習演算法，讓演算法自己從數據中學習如何完成任務。
# 3.  **性能提升 (Performance Improvement)：** 隨著模型接觸到更多的數據和經驗，它會不斷調整和優化其內部參數，使其在未來執行相同任務時表現得更好、更準確。
#
# **機器學習的運作流程簡述：**
#
# 1.  **數據輸入 (Data Input)：** 系統接收大量的數據（例如圖片、文字、數字、聲音等）。
# 2.  **模式識別 (Pattern Recognition)：** 演算法在這些數據中尋找隱藏的關聯、規律和趨勢。
# 3.  **模型建立 (Model Building)：** 根據識別出的模式，系統建立一個「模型」，這個模型就是它學習到的知識和規則。
# 4.  **預測與決策 (Prediction & Decision)：** 當有新的、未見過的數據輸入時，系統會利用這個模型來做出預測、分類或決策。
# 5.  **性能提升 (Performance Improvement)：** 透過不斷地接收新數據和反饋，系統會持續調整和優化其模型，使其性能越來越好。
#
# **常見的應用範例：**
#
# *   **推薦系統：** 根據你的觀看歷史推薦電影或商品（Netflix、Amazon）。
# *   **垃圾郵件過濾：** 識別並將垃圾郵件隔離。
# *   **圖像識別：** 辨識圖片中的物體、人臉或文字（手機解鎖、Google Photos）。
# *   **語音助手：** 理解並回應語音指令（Siri、Google Assistant）。
# *   **自動駕駛：** 讓汽車識別道路、障礙物並做出駕駛決策。
# *   **醫療診斷：** 分析醫學影像或病歷數據來輔助診斷疾病。
#
# 總之，機器學習讓電腦從「被告知怎麼做」轉變為「自己學習怎麼做」，這開啟了許多過去無法實現的智能應用。

# %% [markdown]
# # 串流式對話交談介面

# %%
# 載入 Gradio 套件，用於建立網頁互動介面
import gradio as gr  

# ChatBot 是先前定義的聊天機器人類別
# 以 llm (大型語言模型) 為參數建立一個機器人實例
bot = ChatBot(llm)  

# 定義主要的對話處理函式，支援串流輸出
def chat_function_stream(message, history):
    """
    處理每輪使用者輸入的訊息，並以串流方式回傳回應。
    
    參數：
        message (str)：使用者輸入的文字
        history (list)：對話歷史紀錄，每輪對話包含問答內容
    
    回傳：
        生成器 (generator)：逐步產生回覆的文字片段，可即時在 Gradio 顯示
    """
    # 用於累積完整回覆
    full_response = ""
    
    # 使用 chat_stream 生成器逐步取得模型輸出
    for chunk in bot.chat_stream(message):
        # 將每次生成的片段累加
        full_response += chunk
        # 使用 yield 將目前累積的回覆回傳給 Gradio
        yield full_response

# 建立 Gradio 聊天介面
# - chat_function_stream：每次使用者輸入時呼叫的函式
webui = gr.ChatInterface(chat_function_stream)

# 啟動 Gradio 網頁伺服器
# 使用者可透過瀏覽器訪問本機介面 (例如 http://127.0.0.1:7860)
webui.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
