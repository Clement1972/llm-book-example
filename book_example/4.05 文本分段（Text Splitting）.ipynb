# %% [markdown]
# # 文本分段

# %% [markdown]
# ## CharacterTextSplitter

# %%
text = '''
[1]機器學習（Machine Learning, ML）是人工智慧（Artificial Intelligence, AI）中最核心、也是最具實務影響力的技術之一。簡單來說，機器學習的目標是讓電腦系統不需要被明確寫出所有規則，也能從資料中學習規律，並對未知情況做出合理預測或決策。這種能力使電腦能夠處理許多傳統程式設計難以應付的問題，例如語音辨識、影像分類、自然語言理解與推薦系統等。

[2]在傳統程式設計中，人類需要先定義清楚所有邏輯與規則，再由電腦依照這些規則執行。然而，現實世界的問題往往充滿不確定性與例外，規則難以窮舉。機器學習則反其道而行，透過大量資料與演算法，讓模型自行歸納出隱含的規律，並將這些規律以數學模型的形式保存下來。當新資料出現時，模型便能根據過去的學習經驗做出判斷。

[3]從數學角度來看，機器學習的核心在於建立一個函數模型，使輸入資料（特徵）能夠對應到正確的輸出（標籤或預測結果）。模型的學習過程通常包含三個要素：資料、模型與學習策略。資料提供學習的基礎，模型定義了可學習的結構，而學習策略則透過損失函數與最佳化方法，逐步調整模型參數，使預測結果與真實答案的差距最小化。

[4]依照是否提供正確答案，機器學習大致可分為三種類型。第一種是監督式學習，也是最常見的形式。此類方法使用已標註答案的資料進行訓練，例如垃圾郵件分類、房價預測與影像辨識。模型透過比較預測結果與正確標籤之間的誤差，不斷修正自身參數。第二種是非監督式學習，資料中沒有明確標籤，模型的任務是自行找出資料的結構或分布，例如分群（Clustering）與降維（Dimensionality Reduction）。第三種是強化學習，模型透過與環境互動學習行為策略，並根據回饋的獎勵或懲罰來調整決策方式，常見於遊戲 AI、機器人控制與自動駕駛領域。

[5]隨著運算能力的提升與資料量的爆炸性成長，**深度學習（Deep Learning）**成為近年機器學習發展的重要分支。深度學習以多層神經網路為基礎，能夠自動從原始資料中學習高階特徵，大幅降低人工特徵工程的需求。以影像辨識為例，傳統方法需要人工設計邊緣、角點等特徵，而深度學習模型則能從像素出發，逐層學習出形狀、物體與語意概念。

[6]機器學習的應用已深度融入日常生活。搜尋引擎利用機器學習排序結果，串流平台依使用者行為進行推薦，銀行系統用來偵測詐欺交易，醫療領域則協助疾病診斷與影像判讀。在工業與科研領域中，機器學習也被廣泛應用於品質檢測、預測性維護與科學發現。

[7]然而，機器學習並非萬能。模型的表現高度依賴資料品質，若資料存在偏誤，學習結果也會產生偏差。此外，複雜模型的可解釋性較低，可能帶來信任與倫理問題。因此，在實際應用中，除了追求準確率，也必須重視資料治理、模型評估與風險控管。

[8]總結而言，機器學習是一門結合數學、統計、電腦科學與領域知識的跨領域技術。它讓電腦從「被動執行指令」轉變為「主動從資料中學習」，成為推動現代人工智慧發展的關鍵力量。隨著技術持續演進，機器學習將在更多產業與場景中發揮影響，並深刻改變人類與科技互動的方式。
'''

# %%
len(text)
# Out:
# 1304

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=200
)

chunks = text_splitter.split_text(text)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}  [len={len(chunk)}]:\n{chunk}\n")
# Out:
# Chunk 1  [len=347]:
# [1]機器學習（Machine Learning, ML）是人工智慧（Artificial Intelligence, AI）中最核心、也是最具實務影響力的技術之一。簡單來說，機器學習的目標是讓電腦系統不需要被明確寫出所有規則，也能從資料中學習規律，並對未知情況做出合理預測或決策。這種能力使電腦能夠處理許多傳統程式設計難以應付的問題，例如語音辨識、影像分類、自然語言理解與推薦系統等。
#
# [2]在傳統程式設計中，人類需要先定義清楚所有邏輯與規則，再由電腦依照這些規則執行。然而，現實世界的問題往往充滿不確定性與例外，規則難以窮舉。機器學習則反其道而行，透過大量資料與演算法，讓模型自行歸納出隱含的規律，並將這些規律以數學模型的形式保存下來。當新資料出現時，模型便能根據過去的學習經驗做出判斷。
#
# Chunk 2  [len=306]:
# [2]在傳統程式設計中，人類需要先定義清楚所有邏輯與規則，再由電腦依照這些規則執行。然而，現實世界的問題往往充滿不確定性與例外，規則難以窮舉。機器學習則反其道而行，透過大量資料與演算法，讓模型自行歸納出隱含的規律，並將這些規律以數學模型的形式保存下來。當新資料出現時，模型便能根據過去的學習經驗做出判斷。
#
# [3]從數學角度來看，機器學習的核心在於建立一個函數模型，使輸入資料（特徵）能夠對應到正確的輸出（標籤或預測結果）。模型的學習過程通常包含三個要素：資料、模型與學習策略。資料提供學習的基礎，模型定義了可學習的結構，而學習策略則透過損失函數與最佳化方法，逐步調整模型參數，使預測結果與真實答案的差距最小化。
#
# Chunk 3  [len=421]:
# [3]從數學角度來看，機器學習的核心在於建立一個函數模型，使輸入資料（特徵）能夠對應到正確的輸出（標籤或預測結果）。模型的學習過程通常包含三個要素：資料、模型與學習策略。資料提供學習的基礎，模型定義了可學習的結構，而學習策略則透過損失函數與最佳化方法，逐步調整模型參數，使預測結果與真實答案的差距最小化。
#
# ...

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=50
)

chunks = text_splitter.split_text(text)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}  [len={len(chunk)}]:\n{chunk}\n")
# Out:
# Created a chunk of size 194, which is longer than the specified 100
# Created a chunk of size 152, which is longer than the specified 100
# Created a chunk of size 152, which is longer than the specified 100
# Created a chunk of size 267, which is longer than the specified 100
# Created a chunk of size 166, which is longer than the specified 100
# Created a chunk of size 117, which is longer than the specified 100
# Created a chunk of size 113, which is longer than the specified 100
# Chunk 1  [len=193]:
# [1]機器學習（Machine Learning, ML）是人工智慧（Artificial Intelligence, AI）中最核心、也是最具實務影響力的技術之一。簡單來說，機器學習的目標是讓電腦系統不需要被明確寫出所有規則，也能從資料中學習規律，並對未知情況做出合理預測或決策。這種能力使電腦能夠處理許多傳統程式設計難以應付的問題，例如語音辨識、影像分類、自然語言理解與推薦系統等。
#
# Chunk 2  [len=152]:
# [2]在傳統程式設計中，人類需要先定義清楚所有邏輯與規則，再由電腦依照這些規則執行。然而，現實世界的問題往往充滿不確定性與例外，規則難以窮舉。機器學習則反其道而行，透過大量資料與演算法，讓模型自行歸納出隱含的規律，並將這些規律以數學模型的形式保存下來。當新資料出現時，模型便能根據過去的學習經驗做出判斷。
#
# Chunk 3  [len=152]:
# ...

# %% [markdown]
# ## RecursiveCharacterTextSplitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=50
)

chunks = text_splitter.split_text(text)

for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}  [len={len(chunk)}]:\n{chunk}\n")
# Out:
# Chunk 1  [len=59]:
# [1]機器學習（Machine Learning, ML）是人工智慧（Artificial Intelligence,
#
# Chunk 2  [len=99]:
# AI）中最核心、也是最具實務影響力的技術之一。簡單來說，機器學習的目標是讓電腦系統不需要被明確寫出所有規則，也能從資料中學習規律，並對未知情況做出合理預測或決策。這種能力使電腦能夠處理許多傳統程式設
#
# Chunk 3  [len=84]:
# 所有規則，也能從資料中學習規律，並對未知情況做出合理預測或決策。這種能力使電腦能夠處理許多傳統程式設計難以應付的問題，例如語音辨識、影像分類、自然語言理解與推薦系統等。
#
# Chunk 4  [len=99]:
# [2]在傳統程式設計中，人類需要先定義清楚所有邏輯與規則，再由電腦依照這些規則執行。然而，現實世界的問題往往充滿不確定性與例外，規則難以窮舉。機器學習則反其道而行，透過大量資料與演算法，讓模型自行歸
#
# Chunk 5  [len=100]:
# 的問題往往充滿不確定性與例外，規則難以窮舉。機器學習則反其道而行，透過大量資料與演算法，讓模型自行歸納出隱含的規律，並將這些規律以數學模型的形式保存下來。當新資料出現時，模型便能根據過去的學習經驗做出
#
# Chunk 6  [len=53]:
# 納出隱含的規律，並將這些規律以數學模型的形式保存下來。當新資料出現時，模型便能根據過去的學習經驗做出判斷。
#
# Chunk 7  [len=99]:
# [3]從數學角度來看，機器學習的核心在於建立一個函數模型，使輸入資料（特徵）能夠對應到正確的輸出（標籤或預測結果）。模型的學習過程通常包含三個要素：資料、模型與學習策略。資料提供學習的基礎，模型定義
#
# Chunk 8  [len=100]:
# 標籤或預測結果）。模型的學習過程通常包含三個要素：資料、模型與學習策略。資料提供學習的基礎，模型定義了可學習的結構，而學習策略則透過損失函數與最佳化方法，逐步調整模型參數，使預測結果與真實答案的差距最
#
# Chunk 9  [len=53]:
# 了可學習的結構，而學習策略則透過損失函數與最佳化方法，逐步調整模型參數，使預測結果與真實答案的差距最小化。
#
# ...

# %% [markdown]
# ## 對Document進行分段

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("data/CV.pdf")
documents = loader.load()

from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,
    chunk_overlap=10
)

split_docs = text_splitter.split_documents(documents)

print(f"原始文件數量：{len(documents)}")
print(f"分段後文件數量：{len(split_docs)}")

print(split_docs[0].page_content)
print(split_docs[0].metadata)
# Out:
# 原始文件數量：3
# 分段後文件數量：29
# 姓名：陳仁政
#
# 出生年份：1972
#
# 學術與專業背景：
#  博士學位｜中原大學電子研究所
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-04-13T12:57:37+08:00', 'author': '', 'moddate': '2025-04-13T12:57:37+08:00', 'title': 'Microsoft Word - CV.docx', 'source': 'data/CV.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ## MarkdownHeaderTextSplitter

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

markdown_text = """
# 第一章 簡介
大型語言模型是近年 AI 的核心技術。

## 1.1 背景
它結合了深度學習與大數據。

## 1.2 應用
常見於聊天機器人與文件問答。
"""

headers_to_split_on = [
    ("#", "chapter"),
    ("##", "section")
]

splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on
)

docs = splitter.split_text(markdown_text)

for doc in docs:
    print(doc.page_content)
    print(doc.metadata)
# Out:
# 大型語言模型是近年 AI 的核心技術。
# {'chapter': '第一章 簡介'}
# 它結合了深度學習與大數據。
# {'chapter': '第一章 簡介', 'section': '1.1 背景'}
# 常見於聊天機器人與文件問答。
# {'chapter': '第一章 簡介', 'section': '1.2 應用'}

# %% [markdown]
# ## HTMLHeaderTextSplitter

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

html_text = """
<html>
  <body>
    <h1>第一章 簡介</h1>
    <p>大型語言模型是近年 AI 的核心技術。</p>

    <h2>1.1 背景</h2>
    <p>它結合了深度學習與大數據。</p>

    <h2>1.2 應用</h2>
    <p>常見於聊天機器人與文件問答。</p>
  </body>
</html>
"""

headers_to_split_on = [
    ("h1", "chapter"),
    ("h2", "section")
]

splitter = HTMLHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on
)

docs = splitter.split_text(html_text)

for doc in docs:
    print(doc.page_content)
    print(doc.metadata)
# Out:
# 第一章 簡介
# {'chapter': '第一章 簡介'}
# 大型語言模型是近年 AI 的核心技術。
# {'chapter': '第一章 簡介'}
# 1.1 背景
# {'chapter': '第一章 簡介', 'section': '1.1 背景'}
# 它結合了深度學習與大數據。
# {'chapter': '第一章 簡介', 'section': '1.1 背景'}
# 1.2 應用
# {'chapter': '第一章 簡介', 'section': '1.2 應用'}
# 常見於聊天機器人與文件問答。
# {'chapter': '第一章 簡介', 'section': '1.2 應用'}
