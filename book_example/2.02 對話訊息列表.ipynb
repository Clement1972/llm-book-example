# %% [markdown]
# # 對話訊息列表

# %% [markdown]
# # 選擇模型
# 請自由任意選擇下面兩個模型之一來進行範例

# %% [markdown]
# ## Gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

API_KEY = "這邊請改成你自己的API_KEY值"
model_name = 'gemini-2.5-flash'

llm = ChatGoogleGenerativeAI(
    model=model_name,
    google_api_key=API_KEY
)

# %% [markdown]
# ## LM Studio (或 Ollama)

# %%
from langchain_openai import ChatOpenAI
model_name = 'gemma-3-12b-it'  # 指定模型名稱，模型名稱會根據下載的模型不同而改變

# 根據使用LM Studio或Ollama來選擇適當的伺服器URL
base_url = 'http://localhost:1234/v1'  # LM Studio 本地伺服器的URL
# base_url = 'http://localhost:11434/v1' # Ollama 本地伺服器的URL

llm = ChatOpenAI(
    model=model_name,
    openai_api_key="not-needed",
    openai_api_base=base_url 
)

# %% [markdown]
# ## 測試模型

# %%
from langchain.messages import HumanMessage
messages = [
    HumanMessage("機器學習的定義")
]
result = llm.invoke(messages)
print(result.content)
# Out:
# **機器學習 (Machine Learning, ML)** 是一種人工智慧 (AI) 的分支，旨在讓電腦系統能夠在沒有明確編程的情況下，從數據中學習並改進其性能。
#
# 更具體地說，機器學習的核心思想是：
#
# 1.  **從數據中學習 (Learn from Data)：** 機器學習算法通過分析大量的訓練數據，自動識別其中的模式、規律和關聯性。
# 2.  **建立模型 (Build Models)：** 根據從數據中學到的模式，算法會建立一個數學模型。
# 3.  **做出預測或決策 (Make Predictions or Decisions)：** 一旦模型建立完成，它就可以用來處理新的、未見過的數據，並基於學到的知識做出預測、分類或決策。
# 4.  **自動改進 (Automatic Improvement)：** 隨著處理的數據量增加（即「經驗」增加），以及通過衡量其性能並進行調整，機器學習模型能夠自動優化其表現，變得更加準確和高效。
#
# **Tom M. Mitchell** 曾給出一個經典的定義：
# 「如果一個電腦程序在任務 T 上的性能（由性能測量 P 衡量）隨著經驗 E 的增加而提高，那麼我們就說它從經驗 E 中學習了。」
#
# **總結來說，機器學習的關鍵特點是：**
#
# *   **數據驅動：** 依賴大量數據進行訓練。
# *   **模式識別：** 自動從數據中發現隱藏的模式。
# *   **無需明確編程：** 無需為每個特定任務手動編寫詳細的規則，而是讓機器自己從數據中「學習」這些規則。
# *   **適應性和改進：** 能夠隨著時間和新數據的出現而自動調整和優化其性能。
#
# 機器學習廣泛應用於圖像識別、語音識別、推薦系統、自然語言處理、醫療診斷、金融欺詐檢測和自動駕駛等領域。

# %% [markdown]
# # 加入SystemMessage

# %%
from langchain.messages import HumanMessage, SystemMessage
messages = [
    SystemMessage("簡短的回答使用者的問題"),
    HumanMessage("機器學習的定義")
]
result = llm.invoke(messages)
print(result.content)
# Out:
# 機器學習是讓電腦從數據中學習，而不需要明確編程，以執行特定任務或做出預測。

# %%
from langchain.messages import HumanMessage, SystemMessage
messages = [
    SystemMessage("使用文言文來回答問題"),
    HumanMessage("機器學習的定義")
]
result = llm.invoke(messages)
print(result.content)
# Out:
# 機器學習者，蓋謂一術也。其術也，使機器無須人為之詳盡編程，而能自觀數據，察其規律，尋其模式。進而優化其處理特定事務之效能，或作預測，或為決策。此乃以數據為師，日臻其智，以應萬變者也。
#
# 簡而言之：
# 機器學習，乃機器不假人為編程，而能藉數據自學，以提升其能力，或預測，或決策之術也。
